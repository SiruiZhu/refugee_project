# %%
import pandas as pd

# %%
df = pd.read_csv("refugee_total_year.csv")

# %%
df
# Out:
#       Year                                    country   number
# 0     1975                                    Algeria    20350
# 1     1975                                  Argentina    15060
# 2     1975                                   Botswana     2400
# 3     1975                                    Burundi    49500
# 4     1975                                   Cameroon    30000
# 5     1975                                      Congo     5000
# 6     1975                              Côte d'Ivoire   300000
# 7     1975                     Dem. Rep. of the Congo   509050
# 8     1975                                   Ethiopia    11000
# 9     1975                                      Gabon    60000
# 10    1975                                     Greece      510
# 11    1975                                      Kenya     1850
# 12    1975                                    Lesotho      190
# 13    1975                                    Morocco      390
# ...

# %%
df['number'] = df['number'] / 100

# %%
df
# Out:
#       Year                                    country    number
# 0     1975                                    Algeria    203.50
# 1     1975                                  Argentina    150.60
# 2     1975                                   Botswana     24.00
# 3     1975                                    Burundi    495.00
# 4     1975                                   Cameroon    300.00
# 5     1975                                      Congo     50.00
# 6     1975                              Côte d'Ivoire   3000.00
# 7     1975                     Dem. Rep. of the Congo   5090.50
# 8     1975                                   Ethiopia    110.00
# 9     1975                                      Gabon    600.00
# 10    1975                                     Greece      5.10
# 11    1975                                      Kenya     18.50
# 12    1975                                    Lesotho      1.90
# 13    1975                                    Morocco      3.90
# ...

# %%
df.to_csv('refugee_total_year_in100.csv', index=False)
