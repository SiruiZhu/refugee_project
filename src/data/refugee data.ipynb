# %%
import pandas as pd

# %% [markdown]
# ## Read Refugee.csv

# %%
df_refugee = pd.read_csv("refugee.csv")

# %%
df_refugee
# Out:
#         Year Country / territory of asylum/residence  \
# 0       1975                               Argentina
# 1       1975                               Argentina
# 2       1975                               Argentina
# 3       1975                               Argentina
# 4       1975                                 Austria
# 5       1975                                 Burundi
# 6       1975                                 Belgium
# 7       1975                                  Brazil
# 8       1975                                Botswana
# 9       1975                                Botswana
# 10      1975                                Botswana
# 11      1975                                Botswana
# 12      1975                                Botswana
# 13      1975                    Central African Rep.
# 14      1975                                  Canada
# 15      1975                             Switzerland
# 16      1975                                   Chile
# ...

# %%
df_refugee = df_refugee[df_refugee['Origin'] !='Various/Unknown']

# %%
df_refugee.to_csv('refugee_clean.csv',index=False)

# %%
df_refugee.rename(columns = {'Country / territory of asylum/residence':'country'}, inplace=True)
# Out:
# /Users/siruizhu/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/frame.py:3778: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
df_refugee
# Out:
#         Year                 country                            Origin  \
# 0       1975               Argentina  Bolivia (Plurinational State of)
# 1       1975               Argentina                             Chile
# 2       1975               Argentina                           Uruguay
# 5       1975                 Burundi                            Rwanda
# 8       1975                Botswana                            Angola
# 9       1975                Botswana                           Lesotho
# 10      1975                Botswana                           Namibia
# 11      1975                Botswana                      South Africa
# 12      1975                Botswana                          Zimbabwe
# 17      1975           Côte d'Ivoire                            Guinea
# 18      1975                Cameroon                 Equatorial Guinea
# 19      1975  Dem. Rep. of the Congo                            Angola
# ...

# %%
df_refugee.shape
# Out:
# (120764, 4)

# %% [markdown]
# ## delete unknown Orgin countries row

# %%
df_refugee = df_refugee[df_refugee['Origin'] != 'Various/Unknown']

# %%
df_refugee.dtypes
# Out:
# Year                                         int64
# country                                     object
# Origin                                      object
# Refugees (incl. refugee-like situations)    object
# dtype: object

# %%
df_refugee.shape
# Out:
# (120764, 4)

# %%
df_refugee.head()
# Out:
#    Year    country                            Origin  \
# 0  1975  Argentina  Bolivia (Plurinational State of)
# 1  1975  Argentina                             Chile
# 2  1975  Argentina                           Uruguay
# 5  1975    Burundi                            Rwanda
# 8  1975   Botswana                            Angola
#
#   Refugees (incl. refugee-like situations)
# 0                                       90
# 1                                    14400
# 2                                      570
# 5                                    49500
# 8                                     1790

# %%
df_track = df_refugee.groupby('Year').country.value_counts().reset_index(name='numbers_origin')

# %%
df_track
# Out:
#       Year                    country  numbers_origin
# 0     1975                     Zambia              12
# 1     1975    United Rep. of Tanzania               8
# 2     1975                      Kenya               6
# 3     1975                   Botswana               5
# 4     1975                    Morocco               5
# 5     1975                     Turkey               5
# 6     1975     Dem. Rep. of the Congo               4
# 7     1975                  Argentina               3
# 8     1975                 Mozambique               3
# 9     1975                   Thailand               3
# 10    1975                    Algeria               2
# 11    1975                      Sudan               2
# 12    1975                     Uganda               2
# 13    1975                    Burundi               1
# 14    1975                   Cameroon               1
# 15    1975                      Congo               1
# ...

# %%
df_refugee_track = df_track.groupby('Year').numbers_origin.sum().reset_index(name = 'track_number')

# %%
df_refugee_track
# Out:
#     Year  track_number
# 0   1975            74
# 1   1976            67
# 2   1977            77
# 3   1978           100
# 4   1979           111
# 5   1980           156
# 6   1981           163
# 7   1982           204
# 8   1983           202
# 9   1984           215
# 10  1985           252
# 11  1986           228
# 12  1987           223
# 13  1988           316
# 14  1989           392
# 15  1990           500
# 16  1991           564
# 17  1992           694
# 18  1993          1437
# 19  1994          1689
# 20  1995          1834
# 21  1996          2124
# 22  1997          2490
# 23  1998          2944
# 24  1999          2988
# 25  2000          4027
# 26  2001          4258
# 27  2002          4474
# 28  2003          4718
# 29  2004          4842
# 30  2005          4989
# 31  2006          5174
# 32  2007          5448
# 33  2008          5511
# 34  2009          5530
# 35  2010          5855
# 36  2011          5942
# 37  2012          6112
# 38  2013          6460
# ...

# %%
df_refugee_track.to_csv('refugee_track_number.csv',index=False)

# %%
df_refugee.head(50)
# Out:
#     Year                 country                            Origin  \
# 0   1975               Argentina  Bolivia (Plurinational State of)
# 1   1975               Argentina                             Chile
# 2   1975               Argentina                           Uruguay
# 5   1975                 Burundi                            Rwanda
# 8   1975                Botswana                            Angola
# 9   1975                Botswana                           Lesotho
# 10  1975                Botswana                           Namibia
# 11  1975                Botswana                      South Africa
# 12  1975                Botswana                          Zimbabwe
# 17  1975           Côte d'Ivoire                            Guinea
# 18  1975                Cameroon                 Equatorial Guinea
# 19  1975  Dem. Rep. of the Congo                            Angola
# 20  1975  Dem. Rep. of the Congo                           Burundi
# ...

# %%
df_refugee.rename(columns={'Refugees (incl. refugee-like situations)':'value'}, inplace=True)

# %%
df_refugee.head()
# Out:
#    Year    country                            Origin  value
# 0  1975  Argentina  Bolivia (Plurinational State of)     90
# 1  1975  Argentina                             Chile  14400
# 2  1975  Argentina                           Uruguay    570
# 5  1975    Burundi                            Rwanda  49500
# 8  1975   Botswana                            Angola   1790

# %% [markdown]
# ## 2017 data has * because of confidency

# %%
df_refugee = df_refugee[df_refugee['value'] != '*']

# %%
df_refugee.shape
# Out:
# (118699, 4)

# %%
df_refugee['value'].isnull().value_counts()
# Out:
# False    103071
# True      15628
# Name: value, dtype: int64

# %%
df_refugee.dropna(subset=['value'], inplace=True)

# %%
df_refugee.shape
# Out:
# (103071, 4)

# %%
df_refugee.to_csv("refugee_total_clean.csv", index=False)

# %% [markdown]
# ## compare refugee original countries and asmlum provided countries1975, 1995 and 2015

# %%
df_1975 = df_refugee[df_refugee['Year'] ==1975]
df_1975.head()
# Out:
#    Year    country                            Origin  value
# 0  1975  Argentina  Bolivia (Plurinational State of)     90
# 1  1975  Argentina                             Chile  14400
# 2  1975  Argentina                           Uruguay    570
# 5  1975    Burundi                            Rwanda  49500
# 8  1975   Botswana                            Angola   1790

# %%
df_1975.to_csv('refugee1975.csv', index=False)

# %%
df_1995 = df_refugee[df_refugee['Year'] ==1995]
df_1995.head()
# Out:
#       Year      country                  Origin  value
# 8951  1995  Afghanistan  Iran (Islamic Rep. of)      3
# 8952  1995  Afghanistan                    Iraq      2
# 8953  1995  Afghanistan              Tajikistan  19600
# 8954  1995       Angola                 Burundi      2
# 8955  1995       Angola  Dem. Rep. of the Congo  10846

# %%
df_1995.to_csv('refugee1995.csv', index=False)

# %%
df_2015 = df_refugee[df_refugee['Year'] ==2015]
df_2015.head()
# Out:
#         Year      country                  Origin value
# 102455  2015        Aruba                Colombia     1
# 102456  2015        Aruba                    Cuba     1
# 102457  2015  Afghanistan             Afghanistan     0
# 102458  2015  Afghanistan  Iran (Islamic Rep. of)    30
# 102459  2015  Afghanistan                    Iraq     1

# %%
df_2015.to_csv('refugee2015.csv', index=False)

# %%
df_refugee.head()
columns = ['Year', 'value']
df_new =df_refugee[columns]

# %%
df_new['value'] = df_new['value'].astype(int)
# Out:
# /Users/siruizhu/.pyenv/versions/3.6.5/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# # How many refugee for each year in total?

# %%
df_number_year = df_new.groupby('Year').value.sum().reset_index()

# %%
df_number_year.to_csv('refugees_year_intotal.csv', index=False)

# %%
df_total = pd.read_csv("refugees_year_intotal.csv")
df_total.head()
# Out:
#    Year    value
# 0  1975  1603840
# 1  1976  1798020
# 2  1977  2335095
# 3  1978  3209640
# 4  1979  4379520

# %% [markdown]
# ## How many people do each country take each year?

# %%
world = pd.read_csv('world-cities.csv')
world.head()
# Out:
#                city        city_ascii        lat        lng  population  \
# 0             'Ataq             'Ataq  14.550003  46.800001     37315.0
# 1  's-Hertogenbosch  's-Hertogenbosch  51.683337   5.316660    134520.0
# 2        25 de Mayo        25 de Mayo -37.800033 -67.683295     17430.0
# 3   28 de Noviembre   28 de Noviembre -51.650040 -72.300016      5300.0
# 4           Aalborg           Aalborg  57.033714   9.916593    111917.5
#
#        country iso2 iso3       province
# 0        Yemen   YE  YEM        Shabwah
# 1  Netherlands   NL  NLD  Noord-Brabant
# 2    Argentina   AR  ARG      Río Negro
# 3    Argentina   AR  ARG     Santa Cruz
# 4      Denmark   DK  DNK    Nordjylland

# %%
# df['Column 1'].append(df['Column 2']).reset_index(drop=True)

# %%
# df.drop(['B', 'C'], axis=1)
world = world.drop(['city', 'city_ascii', 'population','iso2','iso3','province'], axis=1)

# %%
world.head()
# Out:
#          lat        lng      country
# 0  14.550003  46.800001        Yemen
# 1  51.683337   5.316660  Netherlands
# 2 -37.800033 -67.683295    Argentina
# 3 -51.650040 -72.300016    Argentina
# 4  57.033714   9.916593      Denmark

# %%
world.shape
# Out:
# (7312, 3)

# %%
world= world.drop_duplicates(subset = 'country', keep='first', inplace=False)

# %%
world.shape
# Out:
# (223, 3)

# %% [markdown]
# ### yeah 1975

# %%
df_1975 = pd.read_csv('refugee1975.csv')
df_1975.head(50)
# Out:
#     Year                 country                            Origin   value
# 0   1975               Argentina  Bolivia (Plurinational State of)      90
# 1   1975               Argentina                             Chile   14400
# 2   1975               Argentina                           Uruguay     570
# 3   1975                 Burundi                            Rwanda   49500
# 4   1975                Botswana                            Angola    1790
# 5   1975                Botswana                           Lesotho     190
# 6   1975                Botswana                           Namibia     150
# 7   1975                Botswana                      South Africa     190
# 8   1975                Botswana                          Zimbabwe      80
# 9   1975           Côte d'Ivoire                            Guinea  300000
# 10  1975                Cameroon                 Equatorial Guinea   30000
# ...

# %%
df_1975.shape
# Out:
# (73, 4)

# %%
df_1975_country = df_1975['country'].append(df_1975['Origin']).reset_index(drop=True).reset_index(name='country')
df_1975_country
# Out:
#      index                                country
# 0        0                              Argentina
# 1        1                              Argentina
# 2        2                              Argentina
# 3        3                                Burundi
# 4        4                               Botswana
# 5        5                               Botswana
# 6        6                               Botswana
# 7        7                               Botswana
# 8        8                               Botswana
# 9        9                          Côte d'Ivoire
# 10      10                               Cameroon
# 11      11                 Dem. Rep. of the Congo
# 12      12                 Dem. Rep. of the Congo
# 13      13                 Dem. Rep. of the Congo
# 14      14                 Dem. Rep. of the Congo
# 15      15                                  Congo
# 16      16                                Algeria
# 17      17                                Algeria
# ...

# %%
df_1975_country.shape
# Out:
# (146, 2)

# %% [markdown]
# ### delete duplicate rows

# %%
df_1975_country = df_1975_country.drop_duplicates(subset = 'country', keep='first', inplace=False)

# %%
df_1975_country
# Out:
#      index                                country
# 0        0                              Argentina
# 3        3                                Burundi
# 4        4                               Botswana
# 9        9                          Côte d'Ivoire
# 10      10                               Cameroon
# 11      11                 Dem. Rep. of the Congo
# 15      15                                  Congo
# 16      16                                Algeria
# 18      18                               Ethiopia
# 19      19                                  Gabon
# 20      20                                 Greece
# 21      21                                  Kenya
# 27      27                                Lesotho
# 28      28                                Morocco
# 33      33                             Mozambique
# 36      36                                  Nepal
# 37      37                                   Peru
# 38      38                            Philippines
# ...

# %%
df_1975_country = df_1975_country.drop(['index'],axis=1)

# %%
df_1975_country.head()
# Out:
#           country
# 0       Argentina
# 3         Burundi
# 4        Botswana
# 9   Côte d'Ivoire
# 10       Cameroon

# %%
df_1975_country.shape
# Out:
# (52, 1)

# %%
# A.merge(B, left_on='lkey', right_on='rkey', how='outer')
#  result = pd.merge(left, right, on='key')
country_coordinates = pd.merge(world,df_1975_country, on='country',how='right')

# %%
world.shape
# Out:
# (223, 3)

# %%
df_1975_country.shape
# Out:
# (52, 1)

# %%
country_coordinates
# Out:
#           lat         lng                                country
# 0  -37.800033  -67.683295                              Argentina
# 1   31.017085   -2.733306                                Algeria
# 2  -13.639595  -72.890006                                   Peru
# 3    3.983696   13.183319                               Cameroon
# 4   23.714056  -15.936811                                Morocco
# 5   11.770404   34.349986                                  Sudan
# 6   36.994989   35.320004                                 Turkey
# 7    9.033310   38.700004                               Ethiopia
# 8    3.361389   31.809722                                 Uganda
# 9   38.621763   21.407727                                 Greece
# 10 -34.199994  -54.750002                                Uruguay
# 11  46.077003   23.580001                                Romania
# 12  39.000344   -1.870000                                  Spain
# ...

# %%
country_coordinates.shape
# Out:
# (52, 3)

# %%
country_coordinates.to_csv('country_coordinates.csv', index=False)

# %%
df_1975_country[df_1975_country['country'] == 'Bolivia (Plurinational State of)']
# Out:
#                              country
# 73  Bolivia (Plurinational State of)

# %%
country_coordinates[country_coordinates['country'] == 'Dem. Rep. of the Congo']
# Out:
#     lat  lng                 country
# 41  NaN  NaN  Dem. Rep. of the Congo

# %% [markdown]
# ### year 1995

# %%
df_1995 = pd.read_csv('refugee1995.csv')
df_1995.head()
# Out:
#    Year      country                  Origin  value
# 0  1995  Afghanistan  Iran (Islamic Rep. of)      3
# 1  1995  Afghanistan                    Iraq      2
# 2  1995  Afghanistan              Tajikistan  19600
# 3  1995       Angola                 Burundi      2
# 4  1995       Angola  Dem. Rep. of the Congo  10846

# %%
df_1995_country = df_1995['country'].append(df_1995['Origin']).reset_index(drop=True).reset_index(name='country')
df_1995_country.head()
# Out:
#    index      country
# 0      0  Afghanistan
# 1      1  Afghanistan
# 2      2  Afghanistan
# 3      3       Angola
# 4      4       Angola

# %%
df_1995_country = df_1995_country.drop_duplicates(subset = 'country', keep='first', inplace=False)

# %%
df_1995_country = df_1995_country.drop(['index'],axis=1)

# %%
df_1995_country.shape
# Out:
# (182, 1)

# %%
country_coordinates_1995 = pd.merge(world,df_1995_country, on='country',how='right')

# %%
country_coordinates_1995.shape
# Out:
# (182, 3)

# %%
country_coordinates_1995
# Out:
#            lat         lng                                    country
# 0    14.550003   46.800001                                      Yemen
# 1    51.683337    5.316660                                Netherlands
# 2   -37.800033  -67.683295                                  Argentina
# 3    57.033714    9.916593                                    Denmark
# 4    47.390004    8.034004                                Switzerland
# 5     5.100398    7.349980                                    Nigeria
# 6    31.017085   -2.733306                                    Algeria
# 7    -1.724531  -48.884880                                     Brazil
# 8   -26.029588  -55.940007                                   Paraguay
# 9   -13.639595  -72.890006                                       Peru
# 10  -10.042605  148.565030                           Papua New Guinea
# 11   49.050377 -122.299987                                     Canada
# ...

# %%
country_coordinates_1995[country_coordinates_1995['lat'].isnull()]
# Out:
#      lat  lng                                    country
# 151  NaN  NaN                                    Bahamas
# 152  NaN  NaN           Bolivia (Plurinational State of)
# 153  NaN  NaN                       Central African Rep.
# 154  NaN  NaN                              Côte d'Ivoire
# 155  NaN  NaN                     Dem. Rep. of the Congo
# 156  NaN  NaN                                      Congo
# 157  NaN  NaN                             Dominican Rep.
# 158  NaN  NaN                                     Gambia
# 159  NaN  NaN                              Guinea-Bissau
# 160  NaN  NaN                       China, Hong Kong SAR
# 161  NaN  NaN                     Iran (Islamic Rep. of)
# 162  NaN  NaN                              Rep. of Korea
# 163  NaN  NaN                           China, Macao SAR
# 164  NaN  NaN  The former Yugoslav Republic of Macedonia
# 165  NaN  NaN      Serbia and Kosovo (S/RES/1244 (1999))
# ...

# %%
country_coordinates_1995.to_csv('country_coordinates_1995.csv', index=False)

# %%
country_coordinates_1995[country_coordinates_1995['country'] == 'Stateless']
# Out:
#      lat  lng    country
# 171  NaN  NaN  Stateless

# %% [markdown]
# ### 2015 map

# %%
df_2015 = pd.read_csv('refugee2015.csv')
df_2015.head()
# Out:
#    Year      country                  Origin  value
# 0  2015        Aruba                Colombia      1
# 1  2015        Aruba                    Cuba      1
# 2  2015  Afghanistan             Afghanistan      0
# 3  2015  Afghanistan  Iran (Islamic Rep. of)     30
# 4  2015  Afghanistan                    Iraq      1

# %%
df_2015_country = df_2015['country'].append(df_2015['Origin']).reset_index(drop=True).reset_index(name='country')
df_2015_country.head()
# Out:
#    index      country
# 0      0        Aruba
# 1      1        Aruba
# 2      2  Afghanistan
# 3      3  Afghanistan
# 4      4  Afghanistan

# %%
df_2015_country = df_2015_country.drop_duplicates(subset = 'country', keep='first', inplace=False)

# %%
df_2015_country = df_2015_country.drop(['index'],axis=1)

# %%
country_coordinates_2015 = pd.merge(world,df_2015_country, on='country',how='right')

# %%
country_coordinates_2015.shape
# Out:
# (213, 3)

# %%
country_coordinates_2015[country_coordinates_2015['lat'].isnull()]
# Out:
#      lat  lng                                    country
# 172  NaN  NaN                                   Anguilla
# 173  NaN  NaN                                    Bahamas
# 174  NaN  NaN           Bolivia (Plurinational State of)
# 175  NaN  NaN                          Brunei Darussalam
# 176  NaN  NaN                       Central African Rep.
# 177  NaN  NaN                              Côte d'Ivoire
# 178  NaN  NaN                     Dem. Rep. of the Congo
# 179  NaN  NaN                                      Congo
# 180  NaN  NaN                                 Cabo Verde
# 181  NaN  NaN                                    Curaçao
# 182  NaN  NaN                                 Czech Rep.
# 183  NaN  NaN                             Dominican Rep.
# 184  NaN  NaN           Micronesia (Federated States of)
# 185  NaN  NaN                                     Gambia
# 186  NaN  NaN                              Guinea-Bissau
# ...

# %%
country_coordinates_2015.to_csv('country_coordinates_2015.csv', index=False)

# %% [markdown]
# ### 2017 coordinates

# %%
df_2017 = df_refugee[df_refugee['Year'] ==2017]
df_2017.head()
# Out:
#         Year      country                              Origin  value
# 116195  2017        Aruba                            Colombia      0
# 116197  2017        Aruba  Venezuela (Bolivarian Republic of)      0
# 116198  2017  Afghanistan                         Afghanistan      0
# 116199  2017  Afghanistan              Iran (Islamic Rep. of)     34
# 116201  2017  Afghanistan                            Pakistan  75893

# %%
df_2017_country = df_2017['country'].append(df_2017['Origin']).reset_index(drop=True).reset_index(name='country')
df_2017_country.head()
# Out:
#    index      country
# 0      0        Aruba
# 1      1        Aruba
# 2      2  Afghanistan
# 3      3  Afghanistan
# 4      4  Afghanistan

# %%
df_2017_country = df_2017_country.drop_duplicates(subset = 'country', keep='first', inplace=False)

# %%
df_2017_country = df_2017_country.drop(['index'],axis=1)

# %%
country_coordinates_2017 = pd.merge(world,df_2017_country, on='country',how='right')

# %%
country_coordinates_2017.shape
# Out:
# (206, 3)

# %%
country_coordinates_2017[country_coordinates_2017['lat'].isnull()]
# Out:
#      lat  lng                                    country
# 169  NaN  NaN                                    Bahamas
# 170  NaN  NaN           Bolivia (Plurinational State of)
# 171  NaN  NaN                          Brunei Darussalam
# 172  NaN  NaN                       Central African Rep.
# 173  NaN  NaN                              Côte d'Ivoire
# 174  NaN  NaN                     Dem. Rep. of the Congo
# 175  NaN  NaN                                      Congo
# 176  NaN  NaN                                 Cabo Verde
# 177  NaN  NaN                                    Curaçao
# 178  NaN  NaN                                 Czech Rep.
# 179  NaN  NaN                             Dominican Rep.
# 180  NaN  NaN                                     Gambia
# 181  NaN  NaN                              Guinea-Bissau
# 182  NaN  NaN                       China, Hong Kong SAR
# 183  NaN  NaN                     Iran (Islamic Rep. of)
# ...

# %%
country_coordinates_2017.to_csv('country_coordinates_2017.csv', index=False)

# %% [markdown]
# ### Map for 1975, 1995, 2015

# %%
#result = df1.append([df2, df3])

# %%
result = df_1975.append([df_1995, df_2015])

# %%
result.to_csv('refugee1975_2015.csv',index=False)

# %%
coords_1975 = pd.read_csv("country_coordinates_1975.csv")

# %%
coords_1995 = pd.read_csv("country_coordinates_1995.csv")

# %%
coords_1995
# Out:
#            lat         lng                                    country  year
# 0    14.550003   46.800001                                      Yemen  1995
# 1    51.683337    5.316660                                Netherlands  1995
# 2   -37.800033  -67.683295                                  Argentina  1995
# 3    57.033714    9.916593                                    Denmark  1995
# 4    47.390004    8.034004                                Switzerland  1995
# 5     5.100398    7.349980                                    Nigeria  1995
# 6    31.017085   -2.733306                                    Algeria  1995
# 7    -1.724531  -48.884880                                     Brazil  1995
# 8   -26.029588  -55.940007                                   Paraguay  1995
# 9   -13.639595  -72.890006                                       Peru  1995
# 10  -10.042605  148.565030                           Papua New Guinea  1995
# ...

# %%
coords_2015 = pd.read_csv("country_coordinates_2015.csv")

# %%
coords_1975.insert(loc=3, column='year', value=1975)

# %%
coords_2015
# Out:
#            lat         lng                                    country  year
# 0    14.550003   46.800001                                      Yemen  2015
# 1    51.683337    5.316660                                Netherlands  2015
# 2   -37.800033  -67.683295                                  Argentina  2015
# 3    57.033714    9.916593                                    Denmark  2015
# 4    47.390004    8.034004                                Switzerland  2015
# 5     5.100398    7.349980                                    Nigeria  2015
# 6    31.017085   -2.733306                                    Algeria  2015
# 7    -1.724531  -48.884880                                     Brazil  2015
# 8   -26.029588  -55.940007                                   Paraguay  2015
# 9   -13.639595  -72.890006                                       Peru  2015
# 10  -10.042605  148.565030                           Papua New Guinea  2015
# ...

# %%
coords_1995.insert(loc=3, column='year', value=1995)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-0136205f8464> in <module>()
# ----> 1 coords_1995.insert(loc=3, column='year', value=1995)
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    3217         value = self._sanitize_column(column, value, broadcast=False)
#    3218         self._data.insert(loc, column, value,
# -> 3219                           allow_duplicates=allow_duplicates)
#    3220
#    3221     def assign(self, **kwargs):
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/internals.py in insert(self, loc, item, value, allow_duplicates)
#    4336         if not allow_duplicates and item in self.items:
#    4337             # Should this be a different kind of error??
# ...

# %%
coords_2015.insert(loc=3, column='year', value=2015)

# %%
result = coords_1975.append([coords_1995, coords_2015])

# %%
# result = result.drop_duplicates(subset = 'country', keep='first', inplace=False)

# %%
result
# Out:
#            lat         lng                                    country  year
# 0   -37.800033  -67.683295                                  Argentina  1975
# 1    31.017085   -2.733306                                    Algeria  1975
# 2   -13.639595  -72.890006                                       Peru  1975
# 3     3.983696   13.183319                                   Cameroon  1975
# 4    23.714056  -15.936811                                    Morocco  1975
# 5    11.770404   34.349986                                      Sudan  1975
# 6    36.994989   35.320004                                     Turkey  1975
# 7     9.033310   38.700004                                   Ethiopia  1975
# 8     3.361389   31.809722                                     Uganda  1975
# 9    38.621763   21.407727                                     Greece  1975
# 10  -34.199994  -54.750002                                    Uruguay  1975
# ...

# %%
result.to_csv("country_coordinates_new.csv", index=False)

# %%
df = pd.read_csv('country_coordinates_new.csv')

# %%
df
# Out:
#            lat         lng                                    country  year
# 0   -37.800033  -67.683295                                  Argentina  1975
# 1    31.017085   -2.733306                                    Algeria  1975
# 2   -13.639595  -72.890006                                       Peru  1975
# 3     3.983696   13.183319                                   Cameroon  1975
# 4    23.714056  -15.936811                                    Morocco  1975
# 5    11.770404   34.349986                                      Sudan  1975
# 6    36.994989   35.320004                                     Turkey  1975
# 7     9.033310   38.700004                                   Ethiopia  1975
# 8     3.361389   31.809722                                     Uganda  1975
# 9    38.621763   21.407727                                     Greece  1975
# 10  -34.199994  -54.750002                                    Uruguay  1975
# ...

# %%
result.to_csv("country_coordinates.csv", index=False)

# %% [markdown]
# ### Countries with continents

# %%
country_coordinates = pd.read_csv("country_coordinates.csv")
country_coordinates.head()
# Out:
#          lat        lng    country  year
# 0 -37.800033 -67.683295  Argentina  1975
# 1  31.017085  -2.733306    Algeria  1975
# 2 -13.639595 -72.890006       Peru  1975
# 3   3.983696  13.183319   Cameroon  1975
# 4  23.714056 -15.936811    Morocco  1975

# %%
country_coordinates.shape
# Out:
# (215, 4)

# %%
df_countries = pd.read_csv("countries_continent.csv")
df_countries.head()
# Out:
#              name alpha-2 alpha-3  country-code     iso_3166-2   region  \
# 0     Afghanistan      AF     AFG             4  ISO 3166-2:AF     Asia
# 1   Åland Islands      AX     ALA           248  ISO 3166-2:AX   Europe
# 2         Albania      AL     ALB             8  ISO 3166-2:AL   Europe
# 3         Algeria      DZ     DZA            12  ISO 3166-2:DZ   Africa
# 4  American Samoa      AS     ASM            16  ISO 3166-2:AS  Oceania
#
#         sub-region intermediate-region  region-code  sub-region-code  \
# 0    Southern Asia                 NaN        142.0             34.0
# 1  Northern Europe                 NaN        150.0            154.0
# 2  Southern Europe                 NaN        150.0             39.0
# 3  Northern Africa                 NaN          2.0             15.0
# 4        Polynesia                 NaN          9.0             61.0
#
#    intermediate-region-code
# 0                       NaN
# 1                       NaN
# 2                       NaN
# ...

# %%
df_countries = df_countries.rename(columns = {'name':'country'})

# %%
df_countries2 = pd.read_csv("Countries-Continents.csv")
df_countries2.head()
# Out:
#   Continent   Country
# 0    Africa   Algeria
# 1    Africa    Angola
# 2    Africa     Benin
# 3    Africa  Botswana
# 4    Africa   Burkina

# %%
df_countries2 = df_countries2.rename(columns = {'Country':'country'})

# %%
df_refugee = pd.read_csv("refugee_total_clean.csv")
df_refugee.head()
# Out:
#    Year    country                            Origin  value
# 0  1975  Argentina  Bolivia (Plurinational State of)     90
# 1  1975  Argentina                             Chile  14400
# 2  1975  Argentina                           Uruguay    570
# 3  1975    Burundi                            Rwanda  49500
# 4  1975   Botswana                            Angola   1790

# %%
df_refugee = df_refugee.rename(columns= {'country':'asylum_country','Origin':'country'})

# %%
df_refugee.head()
# Out:
#    Year asylum_country                           country  value
# 0  1975      Argentina  Bolivia (Plurinational State of)     90
# 1  1975      Argentina                             Chile  14400
# 2  1975      Argentina                           Uruguay    570
# 3  1975        Burundi                            Rwanda  49500
# 4  1975       Botswana                            Angola   1790

# %%
#country_coordinates = pd.merge(world,df_1975_country, on='country',how='right')
result = pd.merge(df_refugee, df_countries2, on ='country', how= 'left')

# %%
result.shape
# Out:
# (103071, 5)

# %%
result.head()
# Out:
#    Year asylum_country                           country  value      Continent
# 0  1975      Argentina  Bolivia (Plurinational State of)     90            NaN
# 1  1975      Argentina                             Chile  14400  South America
# 2  1975      Argentina                           Uruguay    570  South America
# 3  1975        Burundi                            Rwanda  49500         Africa
# 4  1975       Botswana                            Angola   1790         Africa

# %%
# result.isnull().sum().sum()

# %%
result.dtypes
# Out:
# Year               int64
# asylum_country    object
# country           object
# value              int64
# Continent         object
# dtype: object

# %%
result.dropna(subset=['value'], inplace=True)

# %%
result.groupby('country').value.sum().reset_index(name = 'total_number')
# Out:
#                                        country  total_number
# 0                                  Afghanistan     131621367
# 1                                      Albania        278477
# 2                                      Algeria        177098
# 3                               American Samoa             0
# 4                                      Andorra           117
# 5                                       Angola      13017118
# 6                                     Anguilla             3
# 7                          Antigua and Barbuda           586
# 8                                    Argentina         14980
# 9                                      Armenia       1834685
# 10                                   Australia           470
# 11                                     Austria           785
# 12                                  Azerbaijan       4065936
# 13                                     Bahamas          1775
# ...

# %%
result.to_csv("country_totalnum.csv", index=False)

# %% [markdown]
# ### countries with continent

# %%
result.head()
# Out:
#    Year asylum_country                           country  value      Continent
# 0  1975      Argentina  Bolivia (Plurinational State of)     90            NaN
# 1  1975      Argentina                             Chile  14400  South America
# 2  1975      Argentina                           Uruguay    570  South America
# 3  1975        Burundi                            Rwanda  49500         Africa
# 4  1975       Botswana                            Angola   1790         Africa

# %%
subset = result.iloc[:,2:5]
subset
# Out:
#                                  country   value      Continent
# 0       Bolivia (Plurinational State of)      90            NaN
# 1                                  Chile   14400  South America
# 2                                Uruguay     570  South America
# 3                                 Rwanda   49500         Africa
# 4                                 Angola    1790         Africa
# 5                                Lesotho     190         Africa
# 6                                Namibia     150         Africa
# 7                           South Africa     190         Africa
# 8                               Zimbabwe      80         Africa
# 9                                 Guinea  300000         Africa
# 10                     Equatorial Guinea   30000         Africa
# 11                                Angola  460000         Africa
# 12                               Burundi   24000         Africa
# 13                                Rwanda   24300         Africa
# ...

# %%
subset.shape
# Out:
# (103071, 3)

# %%
subset.drop_duplicates(subset = 'country', keep='first', inplace=True)

# %%
subset
# Out:
#                                 country   value      Continent
# 0      Bolivia (Plurinational State of)      90            NaN
# 1                                 Chile   14400  South America
# 2                               Uruguay     570  South America
# 3                                Rwanda   49500         Africa
# 4                                Angola    1790         Africa
# 5                               Lesotho     190         Africa
# 6                               Namibia     150         Africa
# 7                          South Africa     190         Africa
# 8                              Zimbabwe      80         Africa
# 9                                Guinea  300000         Africa
# 10                    Equatorial Guinea   30000         Africa
# 12                              Burundi   24000         Africa
# 14                               Zambia     750         Africa
# 17                       Western Sahara   20000            NaN
# ...

# %%
fillna = subset[subset['Continent'].isnull()]

# %%
fillna.to_csv("fillna.csv", index=False)

# %%
df_fill = pd.read_csv("fillna.csv")

# %%
df_fill
# Out:
#                                       country   value  Continent
# 0            Bolivia (Plurinational State of)      90        NaN
# 1                              Western Sahara   20000        NaN
# 2                                  Czech Rep.      50        NaN
# 3                                     Tibetan    8200        NaN
# 4                                    Viet Nam     690        NaN
# 5                      Dem. Rep. of the Congo    4500        NaN
# 6                      Lao People's Dem. Rep.   55510        NaN
# 7       Serbia and Kosovo (S/RES/1244 (1999))     120        NaN
# 8                                 Palestinian    3200        NaN
# 9                     United Rep. of Tanzania      90        NaN
# 10                                    Myanmar  160000        NaN
# 11                             Dominican Rep.      50        NaN
# 12                           Syrian Arab Rep.     500        NaN
# ...

# %%
df_fill.shape()
# Out:
# (51, 3)

# %%
result.shape
# Out:
# (103071, 5)

# %%
result.merge(df_fill, left_on="country", right_on="country", how='left')
# Out:
#         Year          asylum_country                           country  \
# 0       1975               Argentina  Bolivia (Plurinational State of)
# 1       1975               Argentina                             Chile
# 2       1975               Argentina                           Uruguay
# 3       1975                 Burundi                            Rwanda
# 4       1975                Botswana                            Angola
# 5       1975                Botswana                           Lesotho
# 6       1975                Botswana                           Namibia
# 7       1975                Botswana                      South Africa
# 8       1975                Botswana                          Zimbabwe
# 9       1975           Côte d'Ivoire                            Guinea
# 10      1975                Cameroon                 Equatorial Guinea
# 11      1975  Dem. Rep. of the Congo                            Angola
# ...

# %%
expected_result = pd.merge(result, df_fill, on = 'country', how = 'left')

# %%
expected_result
# Out:
#         Year          asylum_country                           country  \
# 0       1975               Argentina  Bolivia (Plurinational State of)
# 1       1975               Argentina                             Chile
# 2       1975               Argentina                           Uruguay
# 3       1975                 Burundi                            Rwanda
# 4       1975                Botswana                            Angola
# 5       1975                Botswana                           Lesotho
# 6       1975                Botswana                           Namibia
# 7       1975                Botswana                      South Africa
# 8       1975                Botswana                          Zimbabwe
# 9       1975           Côte d'Ivoire                            Guinea
# 10      1975                Cameroon                 Equatorial Guinea
# 11      1975  Dem. Rep. of the Congo                            Angola
# ...

# %%
new_column = expected_result['Continent_x'].fillna(expected_result['Continent_y']).reset_index()

# %%
new_column.shape
# Out:
# (103071, 2)

# %%
final_result = result.join(new_column)

# %%
final_result.drop(columns=['Continent'], inplace=True)

# %%
final_result.rename(columns={'Continent_x':'continent'},inplace=True)

# %%
final_result[final_result['continent'] != 'NaN']
# Out:
#         Year          asylum_country                           country  \
# 0       1975               Argentina  Bolivia (Plurinational State of)
# 1       1975               Argentina                             Chile
# 2       1975               Argentina                           Uruguay
# 3       1975                 Burundi                            Rwanda
# 4       1975                Botswana                            Angola
# 5       1975                Botswana                           Lesotho
# 6       1975                Botswana                           Namibia
# 7       1975                Botswana                      South Africa
# 8       1975                Botswana                          Zimbabwe
# 9       1975           Côte d'Ivoire                            Guinea
# 10      1975                Cameroon                 Equatorial Guinea
# 11      1975  Dem. Rep. of the Congo                            Angola
# ...

# %%
final_result = final_result[final_result['value'] != 0]

# %%
final_result.shape
# Out:
# (97086, 6)

# %%
final_result = final_result[final_result['country'] != 'Stateless']

# %%
final_result.shape
# Out:
# (96192, 6)

# %%
final_result.drop(columns = ['index'], inplace=True)

# %%
final_result
# Out:
#         Year          asylum_country                           country  \
# 0       1975               Argentina  Bolivia (Plurinational State of)
# 1       1975               Argentina                             Chile
# 2       1975               Argentina                           Uruguay
# 3       1975                 Burundi                            Rwanda
# 4       1975                Botswana                            Angola
# 5       1975                Botswana                           Lesotho
# 6       1975                Botswana                           Namibia
# 7       1975                Botswana                      South Africa
# 8       1975                Botswana                          Zimbabwe
# 9       1975           Côte d'Ivoire                            Guinea
# 10      1975                Cameroon                 Equatorial Guinea
# 11      1975  Dem. Rep. of the Congo                            Angola
# ...

# %%
final_result.to_csv("refugee_total_continent.csv", index=False)

# %%
df_check = pd.read_csv('refugee_total_continent.csv')
df_check.head(50)
# Out:
#     Year          asylum_country                           country   value  \
# 0   1975               Argentina  Bolivia (Plurinational State of)      90
# 1   1975               Argentina                             Chile   14400
# 2   1975               Argentina                           Uruguay     570
# 3   1975                 Burundi                            Rwanda   49500
# 4   1975                Botswana                            Angola    1790
# 5   1975                Botswana                           Lesotho     190
# 6   1975                Botswana                           Namibia     150
# 7   1975                Botswana                      South Africa     190
# 8   1975                Botswana                          Zimbabwe      80
# 9   1975           Côte d'Ivoire                            Guinea  300000
# 10  1975                Cameroon                 Equatorial Guinea   30000
# ...

# %%
final_result.head()
# Out:
#    Year asylum_country                           country  value      continent
# 0  1975      Argentina  Bolivia (Plurinational State of)     90  South America
# 1  1975      Argentina                             Chile  14400  South America
# 2  1975      Argentina                           Uruguay    570  South America
# 3  1975        Burundi                            Rwanda  49500         Africa
# 4  1975       Botswana                            Angola   1790         Africa

# %%
total_num = final_result.groupby('country').value.sum().reset_index(name = 'total_number')
total_num
# Out:
#                                        country  total_number
# 0                                  Afghanistan     131621367
# 1                                      Albania        278477
# 2                                      Algeria        177098
# 3                                      Andorra           117
# 4                                       Angola      13017118
# 5                                     Anguilla             3
# 6                          Antigua and Barbuda           586
# 7                                    Argentina         14980
# 8                                      Armenia       1834685
# 9                                    Australia           470
# 10                                     Austria           785
# 11                                  Azerbaijan       4065936
# 12                                     Bahamas          1775
# 13                                     Bahrain          3942
# ...

# %%
final_result
# Out:
#         Year          asylum_country                           country  \
# 0       1975               Argentina  Bolivia (Plurinational State of)
# 1       1975               Argentina                             Chile
# 2       1975               Argentina                           Uruguay
# 3       1975                 Burundi                            Rwanda
# 4       1975                Botswana                            Angola
# 5       1975                Botswana                           Lesotho
# 6       1975                Botswana                           Namibia
# 7       1975                Botswana                      South Africa
# 8       1975                Botswana                          Zimbabwe
# 9       1975           Côte d'Ivoire                            Guinea
# 10      1975                Cameroon                 Equatorial Guinea
# 11      1975  Dem. Rep. of the Congo                            Angola
# ...

# %%
#pd.concat([df1, df4], axis=1, join='inner')
df2 = pd.merge(total_num, final_result[['country', 'continent']], how='left', on='country')

# %%
df2 = df2.drop_duplicates(subset = 'country', keep='first', inplace=False).reset_index()

# %%
df2.drop(columns=['index'], inplace=True)

# %%
df2
# Out:
#                                        country  total_number      continent
# 0                                  Afghanistan     131621367           Asia
# 1                                      Albania        278477         Europe
# 2                                      Algeria        177098         Africa
# 3                                      Andorra           117         Europe
# 4                                       Angola      13017118         Africa
# 5                                     Anguilla             3  North America
# 6                          Antigua and Barbuda           586  North America
# 7                                    Argentina         14980  South America
# 8                                      Armenia       1834685         Europe
# 9                                    Australia           470        Oceania
# 10                                     Austria           785         Europe
# ...

# %%
total_num
# Out:
#                                        country  total_number
# 0                                  Afghanistan     131621367
# 1                                      Albania        278477
# 2                                      Algeria        177098
# 3                                      Andorra           117
# 4                                       Angola      13017118
# 5                                     Anguilla             3
# 6                          Antigua and Barbuda           586
# 7                                    Argentina         14980
# 8                                      Armenia       1834685
# 9                                    Australia           470
# 10                                     Austria           785
# 11                                  Azerbaijan       4065936
# 12                                     Bahamas          1775
# 13                                     Bahrain          3942
# ...

# %%
df2.to_csv("country_totalnum_continent.csv", index=False)

# %%
total_num.to_csv("country_totalnum.csv", index=False)

# %%
continent_num = final_result.groupby('continent').value.sum().reset_index(name = 'total_number')
continent_num
# Out:
#        continent  total_number
# 0         Africa     170432945
# 1           Asia     241279552
# 2         Europe      25829707
# 3  North America       5500915
# 4        Oceania         91266
# 5  South America       4919405

# %%
df = pd.read_csv("country_totalnum.csv")
df.head()
# Out:
#        country  total_number
# 0  Afghanistan     131621367
# 1      Albania        278477
# 2      Algeria        177098
# 3      Andorra           117
# 4       Angola      13017118

# %%
df.shape
# Out:
# (211, 2)

# %% [markdown]
# ### Top 50 countries

# %%
df_50 = df2.sort_values(by='total_number',ascending=False).head(50).reset_index()

# %%
df_50
# Out:
#     index                                country  total_number      continent
# 0       0                            Afghanistan     131621367           Asia
# 1      90                                   Iraq      26890069           Asia
# 2     182                       Syrian Arab Rep.      24046584           Asia
# 3      64                               Ethiopia      23094128         Africa
# 4     172                                Somalia      19981191         Africa
# 5     177                                  Sudan      15851297         Africa
# 6     206                               Viet Nam      15154642  North America
# 7       4                                 Angola      13017118         Africa
# 8     155                                 Rwanda      12859697         Africa
# 9      29                                Burundi      12649097         Africa
# 10     53                 Dem. Rep. of the Congo      11072889  South America
# ...

# %%
df_50.drop(columns=['index'], inplace=True)

# %%
df_50
# Out:
#                                   country  total_number      continent
# 0                             Afghanistan     131621367           Asia
# 1                                    Iraq      26890069           Asia
# 2                        Syrian Arab Rep.      24046584           Asia
# 3                                Ethiopia      23094128         Africa
# 4                                 Somalia      19981191         Africa
# 5                                   Sudan      15851297         Africa
# 6                                Viet Nam      15154642  North America
# 7                                  Angola      13017118         Africa
# 8                                  Rwanda      12859697         Africa
# 9                                 Burundi      12649097         Africa
# 10                 Dem. Rep. of the Congo      11072889  South America
# 11                             Mozambique       8718777         Africa
# ...

# %%
df_50.dtypes
# Out:
# country         object
# total_number     int64
# continent       object
# dtype: object

# %%
df_50['total_number'] = df_50['total_number'] / 10000

# %%
df_50
# Out:
#                                   country  total_number      continent
# 0                             Afghanistan    13162.1367           Asia
# 1                                    Iraq     2689.0069           Asia
# 2                        Syrian Arab Rep.     2404.6584           Asia
# 3                                Ethiopia     2309.4128         Africa
# 4                                 Somalia     1998.1191         Africa
# 5                                   Sudan     1585.1297         Africa
# 6                                Viet Nam     1515.4642  North America
# 7                                  Angola     1301.7118         Africa
# 8                                  Rwanda     1285.9697         Africa
# 9                                 Burundi     1264.9097         Africa
# 10                 Dem. Rep. of the Congo     1107.2889  South America
# 11                             Mozambique      871.8777         Africa
# ...

# %%
df_50.to_csv("top50.csv",index=False)

# %% [markdown]
# ### all countries

# %%
df2 = pd.read_csv("country_totalnum_continent.csv")

# %%
df_all = df2.sort_values(by='total_number',ascending=False).reset_index()

# %%
df_all.drop(columns=['index'], inplace=True)

# %%
# df_all['total_number'] = df_all['total_number'] / 10000

# %%
df_all.head()
# Out:
#             country  total_number continent
# 0       Afghanistan     131621367      Asia
# 1              Iraq      26890069      Asia
# 2  Syrian Arab Rep.      24046584      Asia
# 3          Ethiopia      23094128    Africa
# 4           Somalia      19981191    Africa

# %%
df_all.total_number.sum()
# Out:
# 448053790

# %%
df_all.

# %%
df_all.to_csv('all.csv',index=False)

# %% [markdown]
# ### sum up each continent

# %%
df_continent = pd.read_csv("refugee_total_continent.csv")
df_continent.head()
# Out:
#    Year asylum_country                           country  value      continent
# 0  1975      Argentina  Bolivia (Plurinational State of)     90  South America
# 1  1975      Argentina                             Chile  14400  South America
# 2  1975      Argentina                           Uruguay    570  South America
# 3  1975        Burundi                            Rwanda  49500         Africa
# 4  1975       Botswana                            Angola   1790         Africa

# %%
df_continent = df_continent.groupby(['Year','continent']).value.sum().reset_index(name='value')

# %%
df_continent.to_csv('continent_year.csv', index=False)

# %%
df_2 = pd.read_csv("continent_year.csv")

# %%
df_2['value'] = round(df_2['value'] / 10000, 3)

# %%
df_2
# Out:
#      Year      continent     value
# 0    1975         Africa   149.684
# 1    1975           Asia     1.890
# 2    1975         Europe     0.980
# 3    1975  North America     0.074
# 4    1975        Oceania     5.705
# 5    1975  South America     2.051
# 6    1976         Africa   169.759
# 7    1976           Asia     9.548
# 8    1976         Europe     0.106
# 9    1976  South America     0.389
# 10   1977         Africa   206.496
# 11   1977           Asia    26.358
# 12   1977         Europe     0.355
# 13   1977  South America     0.300
# 14   1978         Africa   237.738
# 15   1978           Asia    67.648
# 16   1978         Europe     0.750
# 17   1978  North America    14.515
# 18   1978  South America     0.313
# 19   1979         Africa   312.894
# 20   1979           Asia   122.132
# 21   1979         Europe     0.267
# 22   1979  North America     2.346
# 23   1979  South America     0.313
# 24   1980         Africa   422.240
# 25   1980           Asia   253.464
# ...

# %%
df_2.to_csv('continent_year.csv', index=False)

# %% [markdown]
# ### drop value 0 in 'refugee1975_2015.csv'

# %%
df_years = pd.read_csv('refugee1975_2015.csv')

# %%
df_years
# Out:
#            lat         lng                           country  year
# 0   -37.800033  -67.683295                         Argentina  1975
# 1    31.017085   -2.733306                           Algeria  1975
# 2   -13.639595  -72.890006                              Peru  1975
# 3     3.983696   13.183319                          Cameroon  1975
# 4    23.714056  -15.936811                           Morocco  1975
# 5    11.770404   34.349986                             Sudan  1975
# 6    36.994989   35.320004                            Turkey  1975
# 7     9.033310   38.700004                          Ethiopia  1975
# 8     3.361389   31.809722                            Uganda  1975
# 9    38.621763   21.407727                            Greece  1975
# 10  -34.199994  -54.750002                           Uruguay  1975
# 11   46.077003   23.580001                           Romania  1975
# 12   39.000344   -1.870000                             Spain  1975
# ...

# %%
df_years.to_csv('refugee1975_2015_update.csv',index=False)

# %% [markdown]
# ### focus on USA provide asylum to refugees

# %%
df_filter = pd.read_csv('refugee_total_clean.csv')
df_filter.head()
# Out:
#    Year    country                            Origin  value
# 0  1975  Argentina  Bolivia (Plurinational State of)     90
# 1  1975  Argentina                             Chile  14400
# 2  1975  Argentina                           Uruguay    570
# 3  1975    Burundi                            Rwanda  49500
# 4  1975   Botswana                            Angola   1790

# %%
df_filter = df_filter.groupby(['Year','country','Origin']).value.sum().reset_index()

# %%
df_filter.head()
# Out:
#    Year    country                            Origin  value
# 0  1975    Algeria                             Chile    350
# 1  1975    Algeria                    Western Sahara  20000
# 2  1975  Argentina  Bolivia (Plurinational State of)     90
# 3  1975  Argentina                             Chile  14400
# 4  1975  Argentina                           Uruguay    570

# %%
df_filter.rename(columns={'value':'number'}, inplace=True)

# %%
df_filter.head()
# Out:
#    Year    country                            Origin  number
# 0  1975    Algeria                             Chile     350
# 1  1975    Algeria                    Western Sahara   20000
# 2  1975  Argentina  Bolivia (Plurinational State of)      90
# 3  1975  Argentina                             Chile   14400
# 4  1975  Argentina                           Uruguay     570

# %%
# df_filter['number'] = df_filter['number'] / 100

# %%
df_filter
# Out:
#         Year                 country                            Origin  number
# 0       1975                 Algeria                             Chile     350
# 1       1975                 Algeria                    Western Sahara   20000
# 2       1975               Argentina  Bolivia (Plurinational State of)      90
# 3       1975               Argentina                             Chile   14400
# 4       1975               Argentina                           Uruguay     570
# 5       1975                Botswana                            Angola    1790
# 6       1975                Botswana                           Lesotho     190
# 7       1975                Botswana                           Namibia     150
# 8       1975                Botswana                      South Africa     190
# 9       1975                Botswana                          Zimbabwe      80
# 10      1975                 Burundi                            Rwanda   49500
# ...

# %%
df_filter = df_filter.groupby(['Year','country']).number.sum().reset_index()

# %%
df_filter.to_csv('refugee_total_year.csv',index=False)

# %% [markdown]
# ### America 2017

# %%
df_2017us = df_filter[(df_filter['Year'] == 2017) & (df_filter['country'] == 'United States of America')]

# %%
df_2017us
# Out:
#         Year                   country  \
# 102800  2017  United States of America
# 102801  2017  United States of America
# 102802  2017  United States of America
# 102803  2017  United States of America
# 102804  2017  United States of America
# 102805  2017  United States of America
# 102806  2017  United States of America
# 102807  2017  United States of America
# 102808  2017  United States of America
# 102809  2017  United States of America
# 102810  2017  United States of America
# 102811  2017  United States of America
# 102812  2017  United States of America
# 102813  2017  United States of America
# 102814  2017  United States of America
# 102815  2017  United States of America
# 102816  2017  United States of America
# 102817  2017  United States of America
# 102818  2017  United States of America
# 102819  2017  United States of America
# 102820  2017  United States of America
# 102821  2017  United States of America
# 102822  2017  United States of America
# ...

# %%
df_2017us = df_2017us[df_2017us['number'] != 0]

# %%
df_2017us = df_2017us[df_2017us['Origin'] != 'Stateless']

# %%
df_2017us.to_csv('america2017.csv',index=False)

# %%
df_filter_2017 = df_filter[df_filter['Year'] == 2017]

# %%
df_filter_2017
# Out:
#         Year      country                                 Origin  value
# 98034   2017  Afghanistan                            Afghanistan      0
# 98035   2017  Afghanistan                 Iran (Islamic Rep. of)     34
# 98036   2017  Afghanistan                               Pakistan  75893
# 98037   2017  Afghanistan                             Tajikistan      0
# 98038   2017  Afghanistan                                 Turkey      0
# 98039   2017  Afghanistan                             Uzbekistan      0
# 98040   2017      Albania                            Afghanistan      0
# 98041   2017      Albania                                Algeria      0
# 98042   2017      Albania                                  China     12
# 98043   2017      Albania                 Iran (Islamic Rep. of)     12
# 98044   2017      Albania                                  Libya      0
# 98045   2017      Albania                                Morocco      0
# ...

# %%
df_filter_2017.groupby(['Year','country']).value.sum().sort_values(ascending=False).reset_index()
# Out:
#      Year                             country    value
# 0    2017                              Turkey  3480310
# 1    2017                            Pakistan  1393132
# 2    2017                              Uganda  1350495
# 3    2017                             Lebanon   998876
# 4    2017              Iran (Islamic Rep. of)   979435
# 5    2017                             Germany   942024
# 6    2017                          Bangladesh   932209
# 7    2017                               Sudan   906577
# 8    2017                            Ethiopia   889397
# 9    2017                              Jordan   691010
# 10   2017              Dem. Rep. of the Congo   537074
# 11   2017                               Kenya   431880
# 12   2017                                Chad   411460
# 13   2017                            Cameroon   337367
# 14   2017                               China   321699
# 15   2017             United Rep. of Tanzania   308283
# ...

# %%
df_us = df_filter[df_filter['country'] == 'United States of America'].reset_index(drop=True)

# %%
df_us.rename(columns={'value':'number'}, inplace=True)

# %%
df_us.head()
# Out:
#    Year                   country   number
# 0  1988  United States of America  3764.98
# 1  1989  United States of America  4104.37
# 2  1990  United States of America  4641.20
# 3  1991  United States of America  5130.59
# 4  1992  United States of America  5790.62

# %%
df_us['number'] = df_us['number'] / 100

# %%
df_us.to_csv('america_refugee.csv',index=False)

# %%
df_filter
# Out:
#         Year                 country                            Origin   value
# 0       1975                 Algeria                             Chile     350
# 1       1975                 Algeria                    Western Sahara   20000
# 2       1975               Argentina  Bolivia (Plurinational State of)      90
# 3       1975               Argentina                             Chile   14400
# 4       1975               Argentina                           Uruguay     570
# 5       1975                Botswana                            Angola    1790
# 6       1975                Botswana                           Lesotho     190
# 7       1975                Botswana                           Namibia     150
# 8       1975                Botswana                      South Africa     190
# 9       1975                Botswana                          Zimbabwe      80
# 10      1975                 Burundi                            Rwanda   49500
# ...

# %%
china = df_filter['country'] == 'China'
china2 = df_filter['country'] == 'China, Macao SAR'
china3 = df_filter['country'] == 'China, Hong Kong SAR'

# %%
df_china = df_filter[china & china2].reset_index(drop=True)

# %%
df_china
# Out:
# Empty DataFrame
# Columns: [Year, country, Origin, value]
# Index: []
